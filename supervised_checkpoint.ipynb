# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df = df.drop(["sqft_living15","sqft_lot15"],axis=1)

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# dtype: int64

# %%
df.bathrooms = df.bathrooms.round()

# %%
df.bedrooms = df.bedrooms.round()

# %%
df.floors = df.floors.round()

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3        1.0
# 1      6414100192  20141209T000000  538000.0         3        2.0
# 2      5631500400  20150225T000000  180000.0         2        1.0
# 3      2487200875  20141209T000000  604000.0         4        3.0
# 4      1954400510  20150218T000000  510000.0         3        2.0
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3        2.0
# 21609  6600060120  20150223T000000  400000.0         4        2.0
# 21610  1523300141  20140623T000000  402101.0         2        1.0
# 21611   291310100  20150116T000000  400000.0         3        2.0
# 21612  1523300157  20141015T000000  325000.0         2        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
corr = df.corr()
f, ax = plt.subplots(figsize=(20, 15))
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
def select_case(df):
    global cases 
    if df.yr_built >2000:
        df.cases = "new"
    elif df.yr_built < 2000:
        if df.yr_renovated > 2000:
            df.cases = "newly renovated"
        elif 0< df.yr_renovated < 2000 :
            df.cases = "renovated"
        elif df.yr_renovated == 0:
            df.cases = "old"
    return df.cases

# %%
df['cases'] = df.apply(select_case, axis =1)

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3        1.0
# 1      6414100192  20141209T000000  538000.0         3        2.0
# 2      5631500400  20150225T000000  180000.0         2        1.0
# 3      2487200875  20141209T000000  604000.0         4        3.0
# 4      1954400510  20150218T000000  510000.0         3        2.0
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3        2.0
# 21609  6600060120  20150223T000000  400000.0         4        2.0
# 21610  1523300141  20140623T000000  402101.0         2        1.0
# 21611   291310100  20150116T000000  400000.0         3        2.0
# 21612  1523300157  20141015T000000  325000.0         2        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# ...

# %%
sns.barplot(x=df.cases, y=df.price, estimator=np.median)
# Out:
# <AxesSubplot:xlabel='cases', ylabel='price'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
#extract x and y from our data
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) 

model=LinearRegression()   
model.fit(x_train,y_train)
predicted=model.predict(x_test) 
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("Price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df[["bedrooms","bathrooms","grade","sqft_above","sqft_living","view","waterfront","floors"]] 
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40)

model=LinearRegression() 
model.fit(x_train,y_train)
predicted=model.predict(x_test) 

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 50848922037.98085
# R squared 0.5955303784680697

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.metrics import mean_squared_error
from sklearn import metrics
x= df[["bedrooms","bathrooms","grade","sqft_above","sqft_living","view","waterfront","floors"]]
y= df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40) 
poly=PolynomialFeatures(degree=2)
x_train_fit = poly.fit_transform(x_train) 
x_test_ = poly.fit_transform(x_test)
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  41637934619.816025
# R squared:  0.6687977053973946

# %%
x= df[["sqft_living"]]
y= df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)
poly=PolynomialFeatures(degree=2)
x_train_fit = poly.fit_transform(x_train)
x_test_ = poly.fit_transform(x_test)
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("features")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
# Out:
# MSE:  57683993574.001305
# R squared:  0.5411618946041856

# %%
new_data_list =[[1500,    3,    3.0,    1,    0],
[    2000,    4,    3.0, 0,    500],
[    1000,    2,    2.0, 1,    0],    
[    1600,    3,    3.0, 1,    200],    
[    1020,    3,    2.0, 1,    250]]

# %%
new_data_df = pd.DataFrame(new_data_list,columns=["sqft_living"    ,"bedrooms",    "bathrooms",    "waterfront",    "sqft_basement"])

# %%
new_data_df
# Out:
#    sqft_living  bedrooms  bathrooms  waterfront  sqft_basement
# 0         1500         3        3.0           1              0
# 1         2000         4        3.0           0            500
# 2         1000         2        2.0           1              0
# 3         1600         3        3.0           1            200
# 4         1020         3        2.0           1            250

# %%
df_new = df.append(new_data_df) 
df_new
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 0   7.129301e+09  20141013T000000  221900.0         3        1.0         1180
# 1   6.414100e+09  20141209T000000  538000.0         3        2.0         2570
# 2   5.631500e+09  20150225T000000  180000.0         2        1.0          770
# 3   2.487201e+09  20141209T000000  604000.0         4        3.0         1960
# 4   1.954401e+09  20150218T000000  510000.0         3        2.0         1680
# ..           ...              ...       ...       ...        ...          ...
# 0            NaN              NaN       NaN         3        3.0         1500
# 1            NaN              NaN       NaN         4        3.0         2000
# 2            NaN              NaN       NaN         2        2.0         1000
# 3            NaN              NaN       NaN         3        3.0         1600
# 4            NaN              NaN       NaN         3        2.0         1020
#
# ...

# %%
df_new.reset_index()
# Out:
#        index            id             date     price  bedrooms  bathrooms  \
# 0          0  7.129301e+09  20141013T000000  221900.0         3        1.0
# 1          1  6.414100e+09  20141209T000000  538000.0         3        2.0
# 2          2  5.631500e+09  20150225T000000  180000.0         2        1.0
# 3          3  2.487201e+09  20141209T000000  604000.0         4        3.0
# 4          4  1.954401e+09  20150218T000000  510000.0         3        2.0
# ...      ...           ...              ...       ...       ...        ...
# 21613      0           NaN              NaN       NaN         3        3.0
# 21614      1           NaN              NaN       NaN         4        3.0
# 21615      2           NaN              NaN       NaN         2        2.0
# 21616      3           NaN              NaN       NaN         3        3.0
# 21617      4           NaN              NaN       NaN         3        2.0
#
# ...

# %%
df_new.iloc[-5:,:]
# Out:
#    id date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 NaN  NaN    NaN         3        3.0         1500       NaN     NaN
# 1 NaN  NaN    NaN         4        3.0         2000       NaN     NaN
# 2 NaN  NaN    NaN         2        2.0         1000       NaN     NaN
# 3 NaN  NaN    NaN         3        3.0         1600       NaN     NaN
# 4 NaN  NaN    NaN         3        2.0         1020       NaN     NaN
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           1   NaN        NaN    NaN         NaN              0       NaN
# 1           0   NaN        NaN    NaN         NaN            500       NaN
# 2           1   NaN        NaN    NaN         NaN              0       NaN
# 3           1   NaN        NaN    NaN         NaN            200       NaN
# 4           1   NaN        NaN    NaN         NaN            250       NaN
#
#    yr_renovated  zipcode  lat  long cases
# 0           NaN      NaN  NaN   NaN   NaN
# ...

# %%
x=df_new[["sqft_living","bedrooms","bathrooms","waterfront","sqft_basement"]] 
y=df_new["price"].reset_index(drop = True)
x_train = x.iloc[:-5,:]
y_train = y.iloc[:-5]
model=LinearRegression()
model.fit(x_train,y_train) 
predicted=model.predict(x.iloc[-5:,:])

# %%
predicted
# Out:
# array([1212090.50291589,  516099.92196173, 1089480.74058938,
#        1243471.46282551, 1045137.33680948])
